# %% [markdown]
# # SQL Analysis and Queries
#
# ## Objective
# This notebook covers sql analysis and queries for the SpaceX Falcon 9 launch success prediction project.
#
# ## Contents
# 1. Setup and imports
# 2. Data loading
# 3. Analysis
# 4. Results
# 5. Conclusions

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set display options
pd.set_option('display.max_columns', None)
plt.style.use('seaborn-v0_8')
